# %% [markdown]
# <a href="https://colab.research.google.com/github/ankitadhandha/google_colab/blob/main/pandas_v0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
orders_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/datacamp_data.csv')
orders_df
# Out:
#     index  InvoiceNo StockCode                          Description  Quantity  \
# 0       0     536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1       1     536365     71053                  WHITE METAL LANTERN         6
# 2       2     536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3       3     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4       4     536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ..    ...        ...       ...                                  ...       ...
# 95     95     536378     22352    LUNCH BOX WITH CUTLERY RETROSPOT          6
# 96     96     536378     21212      PACK OF 72 RETROSPOT CAKE CASES       120
# 97     97     536378     21975       PACK OF 60 DINOSAUR CAKE CASES        24
# 98     98     536378     21977   PACK OF 60 PINK PAISLEY CAKE CASES        24
# 99     99     536378     84991          60 TEATIME FAIRY CAKE CASES        24
#
#      InvoiceDate  UnitPrice  CustomerID         Country
# 0   12/1/10 8:26       2.55       17850  United Kingdom
# 1   12/1/10 8:26       3.39       17850  United Kingdom
# 2   12/1/10 8:26       2.75       17850  United Kingdom
# 3   12/1/10 8:26       3.39       17850  United Kingdom
# 4   12/1/10 8:26       3.39       17850  United Kingdom
# ..           ...        ...         ...             ...
# 95  12/1/10 9:37       2.55       14688  United Kingdom
# 96  12/1/10 9:37       0.42       14688  United Kingdom
# 97  12/1/10 9:37       0.55       14688  United Kingdom
# 98  12/1/10 9:37       0.55       14688  United Kingdom
# 99  12/1/10 9:37       0.55       14688  United Kingdom
#
# [100 rows x 9 columns]

# %% [markdown]
# # New Section
